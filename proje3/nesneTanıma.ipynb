# %%
import torch
torch.__version__
# Out:
# '2.9.1+cpu'

# %%
from ultralytics import YOLO
model = YOLO("yolov8n.pt")
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolov8n.pt to 'yolov8n.pt': 100% ━━━━━━━━━━━━ 6.2MB 5.1MB/s 1.2s.2s<0.0s0.9s3s

# %%
from ultralytics import YOLO
import cv2
import matplotlib.pyplot as plt

model = YOLO("yolov8n.pt")

img_path = "kedi.jpeg"  # kendi resminin adı
img = cv2.imread(img_path)

results = model(img)

# Sonuçları resme çizdir
output = results[0].plot()

# OpenCV BGR → RGB
output = cv2.cvtColor(output, cv2.COLOR_BGR2RGB)

plt.figure(figsize=(10, 10))
plt.imshow(output)
plt.axis("off")
# Out:
# 0: 448x640 1 cat, 288.8ms
# Speed: 48.4ms preprocess, 288.8ms inference, 13.8ms postprocess per image at shape (1, 3, 448, 640)
# (np.float64(-0.5), np.float64(274.5), np.float64(182.5), np.float64(-0.5))

# %%
from ultralytics import YOLO
import cv2
import matplotlib.pyplot as plt

model = YOLO("yolov8n.pt")

img_path = "araba.jpg"  # kendi resminin adı
img = cv2.imread(img_path)

results = model(img)

# Sonuçları resme çizdir
output = results[0].plot()

# OpenCV BGR → RGB
output = cv2.cvtColor(output, cv2.COLOR_BGR2RGB)

plt.figure(figsize=(10, 10))
plt.imshow(output)
plt.axis("off")
# Out:
# 0: 448x640 1 car, 217.5ms
# Speed: 48.7ms preprocess, 217.5ms inference, 2.3ms postprocess per image at shape (1, 3, 448, 640)
# (np.float64(-0.5), np.float64(2999.5), np.float64(1998.5), np.float64(-0.5))
